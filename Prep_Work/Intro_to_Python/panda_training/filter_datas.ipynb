# %%
import pandas as pd
MyPath = "c:\\Users\\phili\\OneDrive\\Documents\\Formations JEDHA\\Data Essential - Sept 2023\\Prep Work\\Intro to Python\\panda training"
Data = pd.read_csv(MyPath+"/covid-19.csv")
Data = Data.iloc[:, 1:]

# %%
Data.tail()
# Out:
#         dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 685  2020-01-04    4      1  2020      0       0  United_States_of_America
# 686  2020-01-03    3      1  2020      0       0  United_States_of_America
# 687  2020-01-02    2      1  2020      0       0  United_States_of_America
# 688  2020-01-01    1      1  2020      0       0  United_States_of_America
# 689  2019-12-31   31     12  2019      0       0  United_States_of_America
#
#     geoId countryterritoryCode  popData2018 continentExp
# 685    US                  USA  327167434.0      America
# 686    US                  USA  327167434.0      America
# 687    US                  USA  327167434.0      America
# 688    US                  USA  327167434.0      America
# 689    US                  USA  327167434.0      America

# %%
Data["geoId"] == "BE"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 685    False
# 686    False
# 687    False
# 688    False
# 689    False
# Name: geoId, Length: 690, dtype: bool

# %%
TheMask = Data["geoId"] == "BE"
Data[TheMask]
# Out:
#         dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0    2020-04-23   23      4  2020    933     264                 Belgium
# 1    2020-04-22   22      4  2020    973     170                 Belgium
# 2    2020-04-21   21      4  2020   1487     145                 Belgium
# 3    2020-04-20   20      4  2020   1313     230                 Belgium
# 4    2020-04-19   19      4  2020   1045     290                 Belgium
# ..          ...  ...    ...   ...    ...     ...                     ...
# 110  2020-01-04    4      1  2020      0       0                 Belgium
# 111  2020-01-03    3      1  2020      0       0                 Belgium
# 112  2020-01-02    2      1  2020      0       0                 Belgium
# 113  2020-01-01    1      1  2020      0       0                 Belgium
# 114  2019-12-31   31     12  2019      0       0                 Belgium
#
#     geoId countryterritoryCode  popData2018 continentExp
# 0      BE                  BEL   11422068.0       Europe
# 1      BE                  BEL   11422068.0       Europe
# 2      BE                  BEL   11422068.0       Europe
# 3      BE                  BEL   11422068.0       Europe
# 4      BE                  BEL   11422068.0       Europe
# ..    ...                  ...          ...          ...
# 110    BE                  BEL   11422068.0       Europe
# 111    BE                  BEL   11422068.0       Europe
# 112    BE                  BEL   11422068.0       Europe
# 113    BE                  BEL   11422068.0       Europe
# 114    BE                  BEL   11422068.0       Europe
#
# [115 rows x 11 columns]

# %%
TheMask = Data["cases"] > 200
Data[TheMask]
# Out:
#         dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 0    2020-04-23   23      4  2020    933     264                   Belgium
# 1    2020-04-22   22      4  2020    973     170                   Belgium
# 2    2020-04-21   21      4  2020   1487     145                   Belgium
# 3    2020-04-20   20      4  2020   1313     230                   Belgium
# 4    2020-04-19   19      4  2020   1045     290                   Belgium
# ..          ...  ...    ...   ...    ...     ...                       ...
# 614  2020-03-15   15      3  2020    777      10  United_States_of_America
# 615  2020-03-14   14      3  2020    511       7  United_States_of_America
# 616  2020-03-13   13      3  2020    351      10  United_States_of_America
# 617  2020-03-12   12      3  2020    287       2  United_States_of_America
# 618  2020-03-11   11      3  2020    271       2  United_States_of_America
#
#     geoId countryterritoryCode  popData2018 continentExp
# 0      BE                  BEL   11422068.0       Europe
# 1      BE                  BEL   11422068.0       Europe
# 2      BE                  BEL   11422068.0       Europe
# 3      BE                  BEL   11422068.0       Europe
# 4      BE                  BEL   11422068.0       Europe
# ..    ...                  ...          ...          ...
# 614    US                  USA  327167434.0      America
# 615    US                  USA  327167434.0      America
# 616    US                  USA  327167434.0      America
# 617    US                  USA  327167434.0      America
# 618    US                  USA  327167434.0      America
#
# [266 rows x 11 columns]
