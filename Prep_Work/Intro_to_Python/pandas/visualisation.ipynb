# %%
import pandas as pd

# %%
# MyPath = "c:/Users/phili/OneDrive/Documents/Formations_JEDHA/Data_Essential_Sept_2023/Prep_Work/Intro_to_Python/panda_training"
# Data = pd.read_csv(MyPath+"/covid-19.csv")
Data = pd.read_csv("./assets/covid-19.csv")
Data = Data.iloc[:, 1:]

# %%
TheMask = Data["geoId"] == "US"
USData = Data[TheMask]
USData.head()
# Out:
#         dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 575  2020-04-23   23      4  2020  17588    1721  United_States_of_America
# 576  2020-04-22   22      4  2020  37289    2524  United_States_of_America
# 577  2020-04-21   21      4  2020  28065    1857  United_States_of_America
# 578  2020-04-20   20      4  2020  24601    1772  United_States_of_America
# 579  2020-04-19   19      4  2020  32922    1856  United_States_of_America
#
#     geoId countryterritoryCode  popData2018 continentExp
# 575    US                  USA  327167434.0      America
# 576    US                  USA  327167434.0      America
# 577    US                  USA  327167434.0      America
# 578    US                  USA  327167434.0      America
# 579    US                  USA  327167434.0      America

# %%
USData.reset_index(drop=True, inplace=True)
USData.head()
# Out:
#       dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 0  2020-04-23   23      4  2020  17588    1721  United_States_of_America
# 1  2020-04-22   22      4  2020  37289    2524  United_States_of_America
# 2  2020-04-21   21      4  2020  28065    1857  United_States_of_America
# 3  2020-04-20   20      4  2020  24601    1772  United_States_of_America
# 4  2020-04-19   19      4  2020  32922    1856  United_States_of_America
#
#   geoId countryterritoryCode  popData2018 continentExp
# 0    US                  USA  327167434.0      America
# 1    US                  USA  327167434.0      America
# 2    US                  USA  327167434.0      America
# 3    US                  USA  327167434.0      America
# 4    US                  USA  327167434.0      America

# %%
# créer une colonne
USData["Cumulated Cases"] = 0
USData.head()
# Out:
# C:\Users\phili\AppData\Local\Temp\ipykernel_1552\1093071318.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   USData["Cumulated Cases"] = 0
#       dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 0  2020-04-23   23      4  2020  17588    1721  United_States_of_America
# 1  2020-04-22   22      4  2020  37289    2524  United_States_of_America
# 2  2020-04-21   21      4  2020  28065    1857  United_States_of_America
# 3  2020-04-20   20      4  2020  24601    1772  United_States_of_America
# 4  2020-04-19   19      4  2020  32922    1856  United_States_of_America
#
#   geoId countryterritoryCode  popData2018 continentExp  Cumulated Cases
# 0    US                  USA  327167434.0      America                0
# ...

# %%
NbRows = len(USData)
print(NbRows)
# Out:
# 115

# %%
# Attention à l'ordre des dates dans le tableau
# On part du fond et on remonte
for i in range (NbRows-2, -1, -1):
    USData.loc[i, "Cumulated Cases"] = USData.loc[i, "cases"] + USData.loc[i+1, "Cumulated Cases"]
USData.head() 
#USData.tail()
# Out:
#       dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 0  2020-04-23   23      4  2020  17588    1721  United_States_of_America
# 1  2020-04-22   22      4  2020  37289    2524  United_States_of_America
# 2  2020-04-21   21      4  2020  28065    1857  United_States_of_America
# 3  2020-04-20   20      4  2020  24601    1772  United_States_of_America
# 4  2020-04-19   19      4  2020  32922    1856  United_States_of_America
#
#   geoId countryterritoryCode  popData2018 continentExp  Cumulated Cases
# 0    US                  USA  327167434.0      America           842629
# 1    US                  USA  327167434.0      America           825041
# 2    US                  USA  327167434.0      America           787752
# 3    US                  USA  327167434.0      America           759687
# 4    US                  USA  327167434.0      America           735086

# %%
USData["New Cases"] = 0
USData.head()
# Out:
# C:\Users\phili\AppData\Local\Temp\ipykernel_1552\1140971387.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   USData["New Cases"] = 0
#       dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 0  2020-04-23   23      4  2020  17588    1721  United_States_of_America
# 1  2020-04-22   22      4  2020  37289    2524  United_States_of_America
# 2  2020-04-21   21      4  2020  28065    1857  United_States_of_America
# 3  2020-04-20   20      4  2020  24601    1772  United_States_of_America
# 4  2020-04-19   19      4  2020  32922    1856  United_States_of_America
#
#   geoId countryterritoryCode  popData2018 continentExp  Cumulated Cases  \
# 0    US                  USA  327167434.0      America           842629
# ...

# %%
# Ca sert à rien on a dejà la colonne cases
for i in range (NbRows-2, -1, -1):
    USData.loc[i, "New Cases"] = USData.loc[i, "Cumulated Cases"] - USData.loc[i+1, "Cumulated Cases"]
USData.head()
# Out:
#       dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 0  2020-04-23   23      4  2020  17588    1721  United_States_of_America
# 1  2020-04-22   22      4  2020  37289    2524  United_States_of_America
# 2  2020-04-21   21      4  2020  28065    1857  United_States_of_America
# 3  2020-04-20   20      4  2020  24601    1772  United_States_of_America
# 4  2020-04-19   19      4  2020  32922    1856  United_States_of_America
#
#   geoId countryterritoryCode  popData2018 continentExp  Cumulated Cases  \
# 0    US                  USA  327167434.0      America           842629
# 1    US                  USA  327167434.0      America           825041
# 2    US                  USA  327167434.0      America           787752
# 3    US                  USA  327167434.0      America           759687
# 4    US                  USA  327167434.0      America           735086
#
#    New Cases
# 0      17588
# 1      37289
# 2      28065
# 3      24601
# 4      32922

# %%
USData["Growth Ratio"] = 0
USData.head()
# Out:
# C:\Users\phili\AppData\Local\Temp\ipykernel_1552\3332186212.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   USData["Growth Ratio"] = 0
#       dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 0  2020-04-23   23      4  2020  17588    1721  United_States_of_America
# 1  2020-04-22   22      4  2020  37289    2524  United_States_of_America
# 2  2020-04-21   21      4  2020  28065    1857  United_States_of_America
# 3  2020-04-20   20      4  2020  24601    1772  United_States_of_America
# 4  2020-04-19   19      4  2020  32922    1856  United_States_of_America
#
#   geoId countryterritoryCode  popData2018 continentExp  Cumulated Cases  \
# 0    US                  USA  327167434.0      America           842629
# ...

# %%
for i in range (NbRows-2, -1, -1):
    USData.loc[i, "Growth Ratio"] = USData.loc[i, "New Cases"] / USData.loc[i+1, "New Cases"]
USData.head()
# Out:
# C:\Users\phili\AppData\Local\Temp\ipykernel_1552\3343804060.py:2: RuntimeWarning: invalid value encountered in scalar divide
#   USData.loc[i, "Growth Ratio"] = USData.loc[i, "New Cases"] / USData.loc[i+1, "New Cases"]
# C:\Users\phili\AppData\Local\Temp\ipykernel_1552\3343804060.py:2: RuntimeWarning: divide by zero encountered in scalar divide
#   USData.loc[i, "Growth Ratio"] = USData.loc[i, "New Cases"] / USData.loc[i+1, "New Cases"]
#       dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 0  2020-04-23   23      4  2020  17588    1721  United_States_of_America
# 1  2020-04-22   22      4  2020  37289    2524  United_States_of_America
# 2  2020-04-21   21      4  2020  28065    1857  United_States_of_America
# 3  2020-04-20   20      4  2020  24601    1772  United_States_of_America
# 4  2020-04-19   19      4  2020  32922    1856  United_States_of_America
#
#   geoId countryterritoryCode  popData2018 continentExp  Cumulated Cases  \
# ...

# %%
# attention l'axe des x est inversé
USData.plot.line(x="dateRep", y="Cumulated Cases")
# Out:
# <Axes: xlabel='dateRep'>

# %%
USData = USData.sort_values("dateRep")
USData.head()
# Out:
#         dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 114  2019-12-31   31     12  2019      0       0  United_States_of_America
# 113  2020-01-01    1      1  2020      0       0  United_States_of_America
# 112  2020-01-02    2      1  2020      0       0  United_States_of_America
# 111  2020-01-03    3      1  2020      0       0  United_States_of_America
# 110  2020-01-04    4      1  2020      0       0  United_States_of_America
#
#     geoId countryterritoryCode  popData2018 continentExp  Cumulated Cases  \
# 114    US                  USA  327167434.0      America                0
# 113    US                  USA  327167434.0      America                0
# 112    US                  USA  327167434.0      America                0
# 111    US                  USA  327167434.0      America                0
# 110    US                  USA  327167434.0      America                0
#
#      New Cases  Growth Ratio
# 114          0           0.0
# ...

# %%
USData.plot.line(x="dateRep", y="Cumulated Cases")
# Out:
# <Axes: xlabel='dateRep'>

# %%
# visu du growth ratio
USData.plot.line(x="dateRep", y="Growth Ratio")

# faut virer le pic à 17.5 en filtrant les valeurs au delà de 7.5
# Out:
# <Axes: xlabel='dateRep'>

# %%
TheMask = USData["Growth Ratio"] <= 7.5
USData[TheMask].plot.line(x="dateRep", y="Growth Ratio")
# Out:
# <Axes: xlabel='dateRep'>

# %%
# C'est mieux car on a les dates qui se suivent bien
# Dans le précédent graphe c'était pas le cas (y avait des trous)
TheMask = USData["dateRep"] >= "2020-02-29"
USData[TheMask].plot.line(x="dateRep", y="Growth Ratio", figsize=(10, 5), grid=True)
# Out:
# <Axes: xlabel='dateRep'>
